# %% [markdown]
# ___
#
# <a href='https://akibkhan.tk/'>![AK.png](attachment:AK.png) </a>
# ___
# <center><em>Content Copyright by Akib Khan </em></center>

# %% [markdown]
# # <CENTER> INTRODUCTION TO MYSQL

# %% [markdown]
# ![MSQL1.png](attachment:MSQL1.png)

# %% [markdown]
# ###  STEPS FOR COMMUNICATING PYTHON WITH MySQL DATABASE

# %% [markdown]
# The following steps are used for establisshing the comminication between python and MySQL database -
#
# 1. import mysql.connector
# 2. Python program must get the connection from MYSQL Database.
# 3. Create an Object of Cursor in python program.
# 4. Design a query, Place it in the object of Cursor, Execute the query in DB SW and gets result from database s/w and Hand         over to the python program .
# 5. Python program the result.
# 6. Close the connection.

# %% [markdown]
# EXPLANATION :
#
# ### 1. import mysql.connector
#
#
#     If python program want to communicate with MYSQL data base software then first we must install mysql-connector and must import
#
#     EXAMPLE:
#
#             import mysql.connector

# %% [markdown]
# ### 2. Python program must get the connection from MYSQL Database.
#
#      If a python program want to get the connection from MYSQL Database then we use a pre-defined function called connect().
#      which is present in mysql.connector module.
#
# SYNTAX :
#
#         varname = mysql.connector.connect (
#                                            host = "DNS",
#                                            user="User Name of MYSQL",
#                                            passwd = "Password of MYSQL"
#                                            )
#
#
#         Here -
#
#         1. varname is an object of <class, mysql.connector.connection>
#                                 (OR)
#         2. connection_url = "username/password@IPaddress/serviceid"
#
#             Example :
#
#                              conibj= mysql.connector.connect (
#                                                                host = "localhost",
#                                                                user="root",
#                                                                passwd = "Akib@1999"
#                                                                )
#                                                 (OR)
#                             conobj = mysql.connector.connect (
#                                                                host = "127.0.0.1",
#                                                                user="root",
#                                                                passwd = "Akib@1999"
#                                                                )
#
#
#                         print('Python program got connection from MYSQL Database')
#
#                         print('type of conobj',type(conobj))    # .......<class 'mysql.connector.Cursor'>

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

connection = mysql.connector.connect(
                              host="localhost",               #hostname
                              user="root",                   # the user who has privilege to the db
                              passwd="Akib@1999",               #password for user
                              )


print("Successfully Connected Python with MYSQL Database ",connection)
# Out:
# Successfully Connected Python with MYSQL Database  <mysql.connector.connection.MySQLConnection object at 0x000002057F9B7460>

# %% [markdown]
# ### 3. Create an Object of Cursor in python program :
#
# The purpose of creating the cursor object is that "To carry the query from python program to database software and bring the result from database software to the python program . Hence an object of cursor acts as driver between python program and database software.
#
# To create an object of cursor, we use a pre-defined function called cursor() which is present in connection class of cx_Oracle module.
#
# SYNTAX :
#
#             varname = connectionobj.cursor()
#
#             Here,
#                     varname is an object of <class,cursor>
#
#              EXAMPLE :
#
#                          import mysql.connector
#
#                         connection = mysql.connector.connect(
#                                                               host="localhost",      #hostname
#                                                               user="root",           # the user who has privilege to the db
#                                                               passwd="Akib@1999",    #password for user
#                                                              )
#
#
#                         print("Successfully Connected Python with MYSQL Database ",connection)
#
#
#                         print("Type connection",type(akibobj))  # .......<class 'mysql.connector.Cursor'>
#
#                         print('Python program got connection from MySQL Database')
#
#                         cur=connection.cursor()
#
#                         print("Type of cur object",type(cur)) # .......<class 'mysql.connector.Cursor'>

# %% [markdown]
# ### 4.  Design a query, Place it in the object of Cursor, Execute the query in DB SW and gets result from database s/w and Hand over to the python program :
#
# To execute a query, we use a pre-defined function called execute(), which is present in cursor class of mysql.connector module
#
# SYNTAX :
#
#             cursorobject.execute(query)

# %% [markdown]
# ![POC2.jpg](attachment:POC2.jpg)
